# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt

# %%
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10, 0.5, 10000)

# %%
plt.hist(pop1, alpha=0.5, label="Population 1")
plt.hist(pop2, alpha=0.5, label="Population 2")
plt.legend(loc="upper right")
plt.show()

# %%
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=0.5, label="sample 1")
plt.hist(sample2, alpha=0.5, label="sample 2")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# 1. Increase the size of your samples from 100 to 1000, then calculate the means and standard deviations for your new samples and create histograms for each. Repeat this again, decreasing the size of your samples to 20. What values change, and what remain the same?

# %% [markdown]
# Expectation: The histgram will become more close to normal distribution because the number of samples will increase. When decrease the number of samples to 20, it will disperse.

# %%
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)

plt.hist(sample1, alpha=0.5, label="sample 1")
plt.hist(sample2, alpha=0.5, label="sample 2")
plt.legend(loc="upper right")
plt.show()

# %%
sample1 = np.random.choice(pop1, 20, replace=True)
sample2 = np.random.choice(pop2, 20, replace=True)

plt.hist(sample1, alpha=0.5, label="sample 1")
plt.hist(sample2, alpha=0.5, label="sample 2")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# Result: When samples increased, overlap part increased. When samples decreased, overlap part decreased

# %%
pop1 = np.random.binomial(10, 0.3, 10000)

# %%
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=0.5, label="sample 1")
plt.hist(sample2, alpha=0.5, label="sample 2")
plt.legend(loc="upper right")
plt.show()

# %%
print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())
diff=sample2.mean()-sample1.mean()
print(diff)

# %%
size = np.array([len(sample1), len(sample2)])
sd = np.array([sample1.std(), sample2.std()])

diff_se = (sum(sd ** 2 / size)) ** 0.5
print(diff/diff_se)

# %%
from scipy.stats import ttest_ind

print(ttest_ind(sample2, sample1, equal_var=False))

# %%
# Out:
# 2.89
# 4.93
# 1.413470905254155
# 1.614032217770141
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c0e758353bbf> in <module>
#       1 difference()
# ----> 2 standard_error()
#       3 values()
#
# <ipython-input-16-fc9ac366321a> in standard_error()
#       4
#       5     diff_se = (sum(sd ** 2 / size)) ** 0.5
# ----> 6     print(diff/diff_se)
#
# NameError: name 'diff' is not defined

# %%
pop1 = np.random.binomial(10, 0.4, 10000)

# %%
# Out:
# 2.89
# 4.93
# 1.413470905254155
# 1.614032217770141
# 2.0399999999999996
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c0e758353bbf> in <module>
#       1 difference()
# ----> 2 standard_error()
#       3 values()
#
# <ipython-input-10-fc9ac366321a> in standard_error()
#       4
#       5     diff_se = (sum(sd ** 2 / size)) ** 0.5
# ----> 6     print(diff/diff_se)
#
# NameError: name 'diff' is not defined
