# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
flights = sns.load_dataset("flights")
print(flights.head(n=4))
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129

# %%
sns.set(style="ticks")

# %% [markdown]
# ### Choose one variable and plot that variable four different ways.

# %%
sns.catplot(x="month", y="passengers", data=flights, height=5, aspect=3)

# %%
plt.figure(figsize=(50,5))
sns.catplot(x="month", y="passengers", kind="box", data=flights,  height=5, aspect=3);

# %%
sns.catplot(x="month", y="passengers", kind="boxen", data=flights,  height=5, aspect=3);

# %%
sns.catplot(x="month", y="passengers", kind="violin", data=flights,  height=5, aspect=3);

# %% [markdown]
# ### Choose two continuous variables, and plot them three different ways.

# %%
anscombe = sns.load_dataset("anscombe")
print(anscombe.head(n=4))
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81

# %%
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=anscombe, col_wrap=2, ci=None, palette="muted", height=4, scatter_kws={"s":50, "alpha":1})

# %%
g = sns.FacetGrid(anscombe, row="y", col="x", margin_titles=True)
bins = np.linspace(0, 60, 13)
g.map(plt.hist, "x", color="steelblue", bins=bins)

# %%
sns.lineplot(x="x", y="y", data=anscombe)

# %% [markdown]
# ### Choose one continuous variable and one categorical variable, and plot them six different ways.

# %%
attentions = sns.load_dataset("attention")
print(attentions.head(n=4))
# Out:
#    Unnamed: 0  subject attention  solutions  score
# 0           0        1   divided          1    2.0
# 1           1        2   divided          1    3.0
# 2           2        3   divided          1    3.0
# 3           3        4   divided          1    5.0

# %%
g = sns.catplot(x="attention", y="score", data=attentions,
                   height=6, kind="bar", palette="pastel", ci=95)
g.despine(left=True)
g.set_ylabels("Score")
g.set_xlabels("Attention")
plt.title('Barplot: Meal Tips by Time and Gender')
plt.show()

# %%
g = sns.pointplot(x="attention", y="score", hue="solutions", data=attentions,
                    kind="strip", palette="pastel",ci=95,dodge=True,join=False)
plt.title('Pointplot: Meal Tips by Time and Gender')
plt.show()

# %%
g = sns.catplot(x="attention", y="score", hue="solutions",
                capsize=.2, palette="YlGnBu_d", height=6, aspect=.75,
                kind="point", data=attentions)
g.despine(left=True)

# %%
sns.pairplot(attentions, hue="attention")

# %%
sns.boxplot(x="attention", y="score", hue="solutions", palette=["m", "g"], data=attentions)
sns.despine(offset=10, trim=True)

# %%
titanic= sns.load_dataset("titanic")
print(titanic.head(n=4))
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False

# %%
g = sns.FacetGrid(data=titanic, col='sex')
g.map(sns.distplot, 'age',kde=False)

# %%
sns.jointplot(x="fare", y="age", data=titanic)

# %%
sns.violinplot(x="sex", y="age", data=titanic, hue="survived", split=True)
