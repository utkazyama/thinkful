# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = ("./yelp_labelled.txt")

yelp_0 = pd.read_csv(data_path, delimiter="\t", header=None)

#Score is either 1 (for positive) or 0 (for negative)
yelp_0.columns = ["review", "score"]

# %%
yelp_0
# Out:
#                                                 review  score
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %% [markdown]
# # Positive Review word counts

# %%
yelp = yelp_0.copy()

# %%
keywords = ['good', 'great', 'expected', 'recommend', 'happy', 'excellent',
                 'wow', 'fast', 'recommended', 'love', 'nice', 'amazing', 'teriffic', 'surprized']

for key in keywords:
    yelp[str(key)] = yelp.review.str.contains((" " + str(key) +" "), case = False)
    yelp[str(key)] = yelp.review.str.contains((str(key) +" "), case = False)
    yelp[str(key)] = yelp.review.str.contains((" " + str(key)), case = False)
    yelp[str(key)] = yelp.review.str.contains((str(key)), case=False)

# %%
yelp
# Out:
#                                                 review  score   good  great  \
# 0                             Wow... Loved this place.      1  False  False
# 1                                   Crust is not good.      0   True  False
# 2            Not tasty and the texture was just nasty.      0  False  False
# 3    Stopped by during the late May bank holiday of...      1  False  False
# 4    The selection on the menu was great and so wer...      1  False   True
# ..                                                 ...    ...    ...    ...
# 995  I think food should have flavor and texture an...      0  False  False
# 996                           Appetite instantly gone.      0  False  False
# 997  Overall I was not impressed and would not go b...      0  False  False
# 998  The whole experience was underwhelming, and I ...      0  False  False
# 999  Then, as if I hadn't wasted enough of my life ...      0  False  False
#
# ...

# %%
yelp["score"] = (yelp["score"] == 1)

yelp
# Out:
#                                                 review  score   good  great  \
# 0                             Wow... Loved this place.   True  False  False
# 1                                   Crust is not good.  False   True  False
# 2            Not tasty and the texture was just nasty.  False  False  False
# 3    Stopped by during the late May bank holiday of...   True  False  False
# 4    The selection on the menu was great and so wer...   True  False   True
# ..                                                 ...    ...    ...    ...
# 995  I think food should have flavor and texture an...  False  False  False
# 996                           Appetite instantly gone.  False  False  False
# 997  Overall I was not impressed and would not go b...  False  False  False
# 998  The whole experience was underwhelming, and I ...  False  False  False
# 999  Then, as if I hadn't wasted enough of my life ...  False  False  False
#
# ...

# %%
sns.heatmap(yelp.corr())

# %% [markdown]
# That is actually a great looking plot for us. Most of the words show strong independence from each other. The only exceptions are free:offer and cash:winner. For now, let's keep everything in the dataset.

# %%
data = yelp[keywords]
target = yelp["score"]

# %%
# Our data is binary / boolean, so we're importing the Bernoulli classifier.
from sklearn.naive_bayes import BernoulliNB

#initiate our model and store it in a new variable
bnb = BernoulliNB()

#fit our model to the data
bnb.fit(data, target)

#classify, storing the result in a new variable
y_pred = bnb.predict(data)
print("Number of mislabeled points out of total {} points : {}".format(data.shape[0], (target != y_pred).sum()))
# Out:
# Number of mislabeled points out of total 1000 points : 311

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(target, y_pred)
# Out:
# array([[464,  36],
#        [275, 225]])

# %%
TP = 0
FP = 0
TN = 0
FN = 0

for i in range(len(y_pred)):
    if target[i] == y_pred[i] ==1:
        TP +=1
    if y_pred[i] == 1 and target[i]!=y_pred[i]:
        FP += 1
    if target[i] == y_pred[i] ==0:
        TN += 1
    if y_pred[i] == 0 and target[i]!=y_pred[i]:
        FN += 1

# %%
target_pos = 0

for i in range(len(target)):
    if target[i] ==1:
        target_pos +=1

print("Sensitivity is : {}".format(100* TP / target_pos))

# Sensitivity is the percentage of positives correctly identified, in our case 198/747 or 27%. This shows how good we are at catching positives, or how sensitive our model is to identifying positives.
# Out:
# Sensitivity is : 45.0

# %%
target_neg = 0

for i in range(len(target)):
    if target[i] == 0:
        target_neg +=1
        
print("Specifity is : {}".format(100*TN/target_neg))

# Specificity is just the opposite, the percentage of negatives correctly identified, 4770/4825 or 99%.
# Out:
# Specifity is : 92.8

# %%
print("Accuracy is : {}".format((TN+TP)*100/(TP+TN+FP+FN)))
# Out:
# Accuracy is : 68.9

# %% [markdown]
# ## Holdout Groups

# %%
# Test your model with different holdout groups.
from sklearn.model_selection import train_test_split

# Use train_test_split to create the necessary training and test groups
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=20)
print("With 20% Holdout: " + str(bnb.fit(X_train, y_train).score(X_test, y_test)))
print("Testing on Sample: " + str(bnb.fit(data, target).score(data, target)))
# Out:
# With 20% Holdout: 0.675
# Testing on Sample: 0.689

# %% [markdown]
# These scores look really consistent! It doesn't seem like our model is overfitting.

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(bnb, data, target, cv=10)
# Out:
# array([0.66, 0.7 , 0.66, 0.74, 0.68, 0.64, 0.68, 0.68, 0.69, 0.74])

# %% [markdown]
# If our model is overfitting at a variable amount, those scores will fluctuate. Instead, ours are relatively consistent.

# %% [markdown]
# # Negative Review word counts

# %%
yelp_n = yelp_0.copy()

badwords = ['bad', 'terrible', 'dissapointed', 'worse', 'worst', 'sad', 'broken', 
                'damaged', 'defective', 'slow', 'problems', 'wasted',
 'hate', 'unacceptible', 'not']

for key in badwords:
    yelp_n[str(i)] = yelp_n.review.str.contains((' ' + str(i) + ' '), case=False)
    yelp_n[str(i)] = yelp_n.review.str.contains((str(i) + ' '), case=False)
    yelp_n[str(i)] = yelp_n.review.str.contains((' ' + str(i)), case=False)
    yelp_n[str(i)] = yelp_n.review.str.contains((str(i)), case=False)
